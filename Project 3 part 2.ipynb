# %% [markdown]
# # James Jones
# ### 11-18-2022

# %%
# Basic imports and inspecting 'Data' folder
import os, time, json
import tmdbsimple as tmdb 
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm_notebook
FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['tmdb_api_results_2000.json',
#  'title_basics.csv.gz',
#  '.ipynb_checkpoints',
#  'title_akas.csv.gz',
#  'title_ratings.csv.gz']

# %%
# Load in TMDB API cedentials
with open('/Users/jamesjones/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['api-key'])

# %%
# Assign API key
tmdb.API_KEY = login['api-key']

# %%
# Define a our function to get movie with the rating (certification) included

def get_movie_with_rating(movie_id):
    # Get the movie object for the current id
    movie_id = tmdb.Movies('imdb_id')

# Save the .info .releases dictionaries
    info = movie.info()
    releases = movie.releases()

# Loop through countries in releases
    for c in releases['countries']:
        if c['iso_3166_1'] == 'US':
        # Save a "certificatio" key in the info dictionary 
            info['certification'] = c['certification']
    return info

# How we built this out will be explained below

# %%
# Define function to write new .json files

def write_json(new_data, filename): 
    # Appends a list of records (new_data) to a json file (filename)
     #Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/
    
    with open(filename, 'r+') as file:
        
        # First we load existing data into a dict.
        file_data = json.load(file)
        
        # Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
                
        # Sets file's current position at offset.
        file.seek(0)
        
        # Convert back to json.
        json.dump(file_data, file)

# %%
# Make a movie object using .Movies function (explained in tmdb)
movie = tmdb.Movies(603)
    # This is a sample run to find where the info our stakeholder wants is stored

# %%
# Movie objects have a .info() dictionary
info = movie.info()
info
# Out:
# {'adult': False,
#  'backdrop_path': '/l4QHerTSbMI7qgvasqxP36pqjN6.jpg',
#  'belongs_to_collection': {'id': 2344,
#   'name': 'The Matrix Collection',
#   'poster_path': '/bV9qTVHTVf0gkW0j7p7M0ILD4pG.jpg',
#   'backdrop_path': '/bRm2DEgUiYciDw3myHuYFInD7la.jpg'},
#  'budget': 63000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': 'http://www.warnerbros.com/matrix',
#  'id': 603,
#  'imdb_id': 'tt0133093',
#  'original_language': 'en',
#  'original_title': 'The Matrix',
#  'overview': 'Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.',
#  'popularity': 60.561,
#  'poster_path': '/f89U3ADr1oiB1s9GkdPOEpXUk5H.jpg',
#  'production_companies': [{'id': 79,
#    'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png',
#    'name': 'Village Roadshow Pictures',
#    'origin_country': 'US'},
#   {'id': 174,
#    'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#    'name': 'Warner Bros. Pictures',
#    'origin_country': 'US'},
#   {'id': 372,
#    'logo_path': None,
#    'name': 'Groucho II Film Partnership',
#    'origin_country': ''},
#   {'id': 1885,
#    'logo_path': '/tXMFoE8AtNdnFzWOW0aCLwl7xxS.png',
#    'name': 'Silver Pictures',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '1999-03-30',
#  'revenue': 463517383,
#  'runtime': 136,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Welcome to the Real World.',
#  'title': 'The Matrix',
#  'video': False,
#  'vote_average': 8.193,
#  'vote_count': 22351}

# %%
# We know our stakeholder is looking for Revenue, Budget, and certification (rating)
    # Certification is not shown in the above output (we'll come back to it)
print(info['budget'])
print(info['revenue'])

# We will also view the imdb_id, which we will need later
print(info['imdb_id'])
# Out:
# 63000000
# 463517383
# tt0133093

# %%
# We can, using our API readme, search our certification
 # Let's try an example
movie = tmdb.Movies('tt0133093')
response = movie.releases()
response
# Out:
# {'id': 603,
#  'countries': [{'certification': '',
#    'iso_3166_1': 'NO',
#    'primary': False,
#    'release_date': '1999-07-07'},
#   {'certification': 'R',
#    'iso_3166_1': 'US',
#    'primary': False,
#    'release_date': '1999-03-24'},
#   {'certification': '',
#    'iso_3166_1': 'FI',
#    'primary': False,
#    'release_date': '1999-06-05'},
#   {'certification': 'M/12',
#    'iso_3166_1': 'PT',
#    'primary': False,
#    'release_date': '1999-06-09'},
#   {'certification': '',
#    'iso_3166_1': 'TH',
#    'primary': False,
#    'release_date': '2021-09-03'},
#   {'certification': 'PG-12',
#    'iso_3166_1': 'JP',
#    'primary': False,
#    'release_date': '1999-09-11'},
#   {'certification': '14A',
#    'iso_3166_1': 'CA',
#    'primary': False,
#    'release_date': '1999-03-30'},
#   {'certification': 'M',
#    'iso_3166_1': 'AU',
#    'primary': False,
#    'release_date': '1999-04-08'},
#   {'certification': '16',
#    'iso_3166_1': 'HU',
#    'primary': False,
#    'release_date': '1999-08-05'},
#   {'certification': '16',
#    'iso_3166_1': 'DE',
#    'primary': False,
#    'release_date': '1999-06-17'},
#   {'certification': 'K-16',
#    'iso_3166_1': 'FI',
#    'primary': False,
#    'release_date': '1999-07-09'},
#   {'certification': '12',
#    'iso_3166_1': 'NL',
#    'primary': False,
#    'release_date': '1999-06-17'},
#   {'certification': 'K-8 ',
#    'iso_3166_1': 'GR',
#    'primary': False,
#    'release_date': '1999-08-20'},
#   {'certification': 'U',
#    'iso_3166_1': 'FR',
#    'primary': False,
#    'release_date': '1999-06-23'},
#   {'certification': 'R',
#    'iso_3166_1': 'US',
#    'primary': False,
#    'release_date': '1999-03-30'},
#   {'certification': '15',
#    'iso_3166_1': 'DK',
#    'primary': False,
#    'release_date': '1999-05-07'},
#   {'certification': 'C',
#    'iso_3166_1': 'BG',
#    'primary': False,
#    'release_date': '1999-09-03'},
#   {'certification': '15',
#    'iso_3166_1': 'NO',
#    'primary': False,
#    'release_date': '1999-07-09'},
#   {'certification': '15',
#    'iso_3166_1': 'GB',
#    'primary': False,
#    'release_date': '1999-06-11'},
#   {'certification': '12',
#    'iso_3166_1': 'CZ',
#    'primary': False,
#    'release_date': '1999-08-05'},
#   {'certification': 'T',
#    'iso_3166_1': 'IT',
#    'primary': False,
#    'release_date': '1999-05-07'},
#   {'certification': '12',
#    'iso_3166_1': 'BR',
#    'primary': False,
#    'release_date': '1999-05-21'},
#   {'certification': '12',
#    'iso_3166_1': 'KR',
#    'primary': False,
#    'release_date': '1999-05-15'},
#   {'certification': '18',
#    'iso_3166_1': 'ES',
#    'primary': False,
#    'release_date': '1999-06-25'},
#   {'certification': '',
#    'iso_3166_1': 'TR',
#    'primary': False,
#    'release_date': '1999-09-03'},
#   {'certification': '15',
#    'iso_3166_1': 'SE',
#    'primary': False,
#    'release_date': '1999-07-14'},
#   {'certification': '',
#    'iso_3166_1': 'PL',
#    'primary': False,
#    'release_date': '1999-08-13'},
#   {'certification': '',
#    'iso_3166_1': 'SI',
#    'primary': False,
#    'release_date': '1999-08-19'},
#   {'certification': '18SG',
#    'iso_3166_1': 'MY',
#    'primary': False,
#    'release_date': '1999-05-06'},
#   {'certification': '16',
#    'iso_3166_1': 'IS',
#    'primary': False,
#    'release_date': '1999-06-25'},
#   {'certification': '',
#    'iso_3166_1': 'HR',
#    'primary': False,
#    'release_date': '1999-08-26'},
#   {'certification': '',
#    'iso_3166_1': 'SK',
#    'primary': False,
#    'release_date': '1999-08-05'},
#   {'certification': '13',
#    'iso_3166_1': 'AR',
#    'primary': False,
#    'release_date': '1999-06-10'},
#   {'certification': '15',
#    'iso_3166_1': 'IE',
#    'primary': False,
#    'release_date': '1999-06-11'},
#   {'certification': 'PG',
#    'iso_3166_1': 'SG',
#    'primary': False,
#    'release_date': '1999-04-22'},
#   {'certification': '12',
#    'iso_3166_1': 'CH',
#    'primary': False,
#    'release_date': '1999-06-23'},
#   {'certification': 'PG-12',
#    'iso_3166_1': 'TW',
#    'primary': False,
#    'release_date': '1999-06-04'},
#   {'certification': 'PG',
#    'iso_3166_1': 'IL',
#    'primary': False,
#    'release_date': '1999-06-24'},
#   {'certification': '',
#    'iso_3166_1': 'PH',
#    'primary': False,
#    'release_date': '1999-05-26'},
#   {'certification': '12',
#    'iso_3166_1': 'CH',
#    'primary': False,
#    'release_date': '1999-06-18'},
#   {'certification': 'G',
#    'iso_3166_1': 'TH',
#    'primary': False,
#    'release_date': '1999-05-21'},
#   {'certification': 'KT/EA ',
#    'iso_3166_1': 'BE',
#    'primary': False,
#    'release_date': '1999-07-07'},
#   {'certification': '',
#    'iso_3166_1': 'RO',
#    'primary': False,
#    'release_date': '1999-09-10'},
#   {'certification': '',
#    'iso_3166_1': 'EE',
#    'primary': False,
#    'release_date': '1999-07-16'},
#   {'certification': '16+',
#    'iso_3166_1': 'RU',
#    'primary': False,
#    'release_date': '1999-10-14'},
#   {'certification': 'B',
#    'iso_3166_1': 'MX',
#    'primary': False,
#    'release_date': '1999-05-21'},
#   {'certification': '',
#    'iso_3166_1': 'UY',
#    'primary': False,
#    'release_date': '1999-07-30'},
#   {'certification': '',
#    'iso_3166_1': 'CO',
#    'primary': False,
#    'release_date': '1999-05-21'},
#   {'certification': '',
#    'iso_3166_1': 'ID',
#    'primary': False,
#    'release_date': '1999-07-03'},
#   {'certification': 'M',
#    'iso_3166_1': 'NZ',
#    'primary': False,
#    'release_date': '1999-04-08'},
#   {'certification': 'M/12',
#    'iso_3166_1': 'PT',
#    'primary': False,
#    'release_date': '1999-06-25'},
#   {'certification': '',
#    'iso_3166_1': 'KW',
#    'primary': False,
#    'release_date': '1999-06-09'},
#   {'certification': '16',
#    'iso_3166_1': 'UA',
#    'primary': False,
#    'release_date': '2019-07-25'},
#   {'certification': '12',
#    'iso_3166_1': 'KR',
#    'primary': False,
#    'release_date': '2019-09-25'},
#   {'certification': '16+',
#    'iso_3166_1': 'RU',
#    'primary': False,
#    'release_date': '2019-10-14'},
#   {'certification': 'IIB',
#    'iso_3166_1': 'HK',
#    'primary': False,
#    'release_date': '1999-05-20'},
#   {'certification': '15',
#    'iso_3166_1': 'GB',
#    'primary': False,
#    'release_date': '2021-12-03'},
#   {'certification': 'PG13',
#    'iso_3166_1': 'SG',
#    'primary': False,
#    'release_date': '2021-12-02'},
#   {'certification': '',
#    'iso_3166_1': 'CN',
#    'primary': False,
#    'release_date': '2000-01-14'},
#   {'certification': 'U',
#    'iso_3166_1': 'FR',
#    'primary': False,
#    'release_date': '1999-09-21'},
#   {'certification': '15',
#    'iso_3166_1': 'SE',
#    'primary': False,
#    'release_date': '2018-05-28'},
#   {'certification': '15',
#    'iso_3166_1': 'SE',
#    'primary': False,
#    'release_date': '2008-11-26'},
#   {'certification': '15',
#    'iso_3166_1': 'SE',
#    'primary': False,
#    'release_date': '1999-12-14'},
#   {'certification': '12',
#    'iso_3166_1': 'NL',
#    'primary': False,
#    'release_date': '2004-12-22'},
#   {'certification': '12',
#    'iso_3166_1': 'NL',
#    'primary': False,
#    'release_date': '2011-01-12'},
#   {'certification': '12',
#    'iso_3166_1': 'BR',
#    'primary': False,
#    'release_date': '2008-10-14'},
#   {'certification': '16+',
#    'iso_3166_1': 'RU',
#    'primary': False,
#    'release_date': '2000-09-12'},
#   {'certification': '16+',
#    'iso_3166_1': 'RU',
#    'primary': False,
#    'release_date': '2009-01-27'},
#   {'certification': '16',
#    'iso_3166_1': 'DE',
#    'primary': False,
#    'release_date': '1999-11-25'},
#   {'certification': '12',
#    'iso_3166_1': 'NL',
#    'primary': False,
#    'release_date': '2002-09-23'}]}

# %% [markdown]
# ### You can see above that we rating, but there are MANY because there are many countries
# - Our stakeholder is ONLY interested in US movies, so we need to select them

# %%
# Here is an example
response = movie.releases()
for c in movie.countries:
    if c['iso_3166_1'] == 'US':
        print(c['certification'])
# Out:
# R
# R

# %% [markdown]
# Now, we know that "info" contains the movie 'revenue' and 'budget', and "releases" contains our 'certification'. We therefore need to pull from both to obtain these 3 pieces of information that our stakeholder is looking for. Let's put it all together

# %%
# Get the movie object for the current id
movie = tmdb.Movies('tt0133093')

# Save the .info .releases dictionaries
info = movie.info()
releases = movie.releases()

# Loop through countries in releases
for c in releases['countries']:
    if c['iso_3166_1'] == 'US':
        # Save a "certificatio" key in the info dictionary 
        info['certification'] = c['certification']
        
# *This is adapted into our get_movie_with_rating_funtion at the begining*

# %%
# Do a check, and see that certification has been included in the bottom!
 # Remember: info was set to tmdb.Movies(603) which included the imdb_id of 'tt0133093' used above
info
# Out:
# {'adult': False,
#  'backdrop_path': '/l4QHerTSbMI7qgvasqxP36pqjN6.jpg',
#  'belongs_to_collection': {'id': 2344,
#   'name': 'The Matrix Collection',
#   'poster_path': '/bV9qTVHTVf0gkW0j7p7M0ILD4pG.jpg',
#   'backdrop_path': '/bRm2DEgUiYciDw3myHuYFInD7la.jpg'},
#  'budget': 63000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': 'http://www.warnerbros.com/matrix',
#  'id': 603,
#  'imdb_id': 'tt0133093',
#  'original_language': 'en',
#  'original_title': 'The Matrix',
#  'overview': 'Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.',
#  'popularity': 60.561,
#  'poster_path': '/f89U3ADr1oiB1s9GkdPOEpXUk5H.jpg',
#  'production_companies': [{'id': 79,
#    'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png',
#    'name': 'Village Roadshow Pictures',
#    'origin_country': 'US'},
#   {'id': 174,
#    'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#    'name': 'Warner Bros. Pictures',
#    'origin_country': 'US'},
#   {'id': 372,
#    'logo_path': None,
#    'name': 'Groucho II Film Partnership',
#    'origin_country': ''},
#   {'id': 1885,
#    'logo_path': '/tXMFoE8AtNdnFzWOW0aCLwl7xxS.png',
#    'name': 'Silver Pictures',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '1999-03-30',
#  'revenue': 463517383,
#  'runtime': 136,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Welcome to the Real World.',
#  'title': 'The Matrix',
#  'video': False,
#  'vote_average': 8.193,
#  'vote_count': 22351,
#  'certification': 'R'}

# %% [markdown]
# ### Our stakeholder is only interested in movies that came out in 2000, 2001, so we need to filter for those

# %%
YEARS_TO_GET = [2000, 2002]

# %%
# Load in Title Basics data created in Part 1 (per our instructions)
basics = pd.read_csv('Data/title_basics.csv.gz')
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  \
# 0                             Kate & Leopold        0     2001.0
# 1  El Tango del Viudo y Su Espejo Deformante        0     2020.0
# 2                 The Other Side of the Wind        0     2018.0
# 3                          The Naked Monster        0     2005.0
# 4                       Crime and Punishment        0     2002.0
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
# Create a for loop to filter (loop) through years
    # OUTER LOOP
for YEARS in tqdm_notebook(YEARS_TO_GET, desc = 'YEARS', position = 0):

# Define the JSON file to store results for year
    # This will show at the beginng 
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEARS}.json'
    
    # Check to see if our file exists
    file_exists = os.path.isfile(JSON_FILE)
    
    # Now, create the file if it exists, or leave it if it does exist
    if file_exists == False:
    
        # Save an empty dict to a new json file to append later
        with open(JSON_FILE, 'w') as f:
            json.dump([{'imdb_id':0}],f)
        
    # Now, save our specifisc years as the current df YEAR = 2000
    df_2000 = basics.loc[basics['startYear'] == YEARS].copy()
    df_2000.head(3)

    # Save movie ids from the year 2000 to a list
    movie_ids = df_2000['tconst'].copy()
    movie_ids

    # Check for any previous data
    previous_df = pd.read_json(JSON_FILE)
    previous_df # Will be empty at first
    
    # Filter out any ids that already exist in our JSON_FILE (helps when returning to our problem later)
    movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]
    
# Get index and movie id from list
    # INNER loop

    for movie_id in tqdm_notebook(movie_ids_to_get,
                                      desc = f'Movies from {YEARS}',
                                      position = 1,
                                      leave = True):
            # Make attempt to retrieve data for movie id
        try:
            temp = get_movie_with_rating(movie_id) # Our first function

                # Extend results of our file with our other function
            write_json(temp, JSON_FILE)

                # Create a short sleep (helps bog down the server less)
            time.sleep(0.02)

            # If it fails, make a dict with just the id
        except Exception as e:
            continue
            
        # Finally, store our info in the JSON_FILE
    final_year_df = pd.read_json(JSON_FILE)
    final_year_df.to_csv(f"{FOLDER} final_tmdb_data_{YEARS}.csv.gz",
                            compression = 'gzip', index = False)
# Out:
# YEARS:   0%|          | 0/2 [00:00<?, ?it/s]
# Movies from 2000:   0%|          | 0/1417 [00:00<?, ?it/s]
# Movies from 2002:   0%|          | 0/1520 [00:00<?, ?it/s]

# %%
final_year_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0133093    0.0  /l4QHerTSbMI7qgvasqxP36pqjN6.jpg
# 2     tt0133093    0.0  /l4QHerTSbMI7qgvasqxP36pqjN6.jpg
# 3     tt0133093    0.0  /l4QHerTSbMI7qgvasqxP36pqjN6.jpg
# 4     tt0133093    0.0  /l4QHerTSbMI7qgvasqxP36pqjN6.jpg
# ...         ...    ...                               ...
# 1516  tt0133093    0.0  /l4QHerTSbMI7qgvasqxP36pqjN6.jpg
# 1517  tt0133093    0.0  /l4QHerTSbMI7qgvasqxP36pqjN6.jpg
# 1518  tt0133093    0.0  /l4QHerTSbMI7qgvasqxP36pqjN6.jpg
# 1519  tt0133093    0.0  /l4QHerTSbMI7qgvasqxP36pqjN6.jpg
# 1520  tt0133093    0.0  /l4QHerTSbMI7qgvasqxP36pqjN6.jpg
#
#                                   belongs_to_collection      budget  \
# 0                                                   NaN         NaN
# 1     {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
# 2     {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
# 3     {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
# 4     {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
# ...                                                 ...         ...
# 1516  {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
# 1517  {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
# 1518  {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
# 1519  {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
# 1520  {'id': 2344, 'name': 'The Matrix Collection', ...  63000000.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 2     [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 3     [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# ...                                                 ...
# 1516  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 1517  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 1518  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 1519  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 1520  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
#
#                               homepage     id original_language  \
# 0                                  NaN    NaN               NaN
# 1     http://www.warnerbros.com/matrix  603.0                en
# 2     http://www.warnerbros.com/matrix  603.0                en
# 3     http://www.warnerbros.com/matrix  603.0                en
# 4     http://www.warnerbros.com/matrix  603.0                en
# ...                                ...    ...               ...
# 1516  http://www.warnerbros.com/matrix  603.0                en
# 1517  http://www.warnerbros.com/matrix  603.0                en
# 1518  http://www.warnerbros.com/matrix  603.0                en
# 1519  http://www.warnerbros.com/matrix  603.0                en
# 1520  http://www.warnerbros.com/matrix  603.0                en
#
#      original_title  ...      revenue  runtime  \
# 0               NaN  ...          NaN      NaN
# 1        The Matrix  ...  463517383.0    136.0
# 2        The Matrix  ...  463517383.0    136.0
# 3        The Matrix  ...  463517383.0    136.0
# 4        The Matrix  ...  463517383.0    136.0
# ...             ...  ...          ...      ...
# 1516     The Matrix  ...  463517383.0    136.0
# 1517     The Matrix  ...  463517383.0    136.0
# 1518     The Matrix  ...  463517383.0    136.0
# 1519     The Matrix  ...  463517383.0    136.0
# 1520     The Matrix  ...  463517383.0    136.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                 ...       ...
# 1516  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1517  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1518  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1519  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1520  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                          tagline       title  video  vote_average vote_count  \
# 0                            NaN         NaN    NaN           NaN        NaN
# 1     Welcome to the Real World.  The Matrix    0.0         8.193    22351.0
# 2     Welcome to the Real World.  The Matrix    0.0         8.193    22351.0
# 3     Welcome to the Real World.  The Matrix    0.0         8.193    22351.0
# 4     Welcome to the Real World.  The Matrix    0.0         8.193    22351.0
# ...                          ...         ...    ...           ...        ...
# 1516  Welcome to the Real World.  The Matrix    0.0         8.193    22351.0
# 1517  Welcome to the Real World.  The Matrix    0.0         8.193    22351.0
# 1518  Welcome to the Real World.  The Matrix    0.0         8.193    22351.0
# 1519  Welcome to the Real World.  The Matrix    0.0         8.193    22351.0
# 1520  Welcome to the Real World.  The Matrix    0.0         8.193    22351.0
#
#      certification
# 0              NaN
# 1                R
# 2                R
# 3                R
# 4                R
# ...            ...
# 1516             R
# 1517             R
# 1518             R
# 1519             R
# 1520             R
#
# [1521 rows x 26 columns]
