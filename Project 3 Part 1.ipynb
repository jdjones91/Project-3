# %% [markdown]
# # James Jones
# ### 11-08-2022

# %%
# Import Libraries
import pandas as pd
import numpy as np

# %%
# Load in URLs
basics_url = 'https://datasets.imdbws.com/title.basics.tsv.gz'
akas_url = 'https://datasets.imdbws.com/title.akas.tsv.gz'
ratings_url = 'https://datasets.imdbws.com/title.ratings.tsv.gz'

# %%
# Read in to DFs
basics = pd.read_csv(basics_url, sep = '\t', low_memory = False)

# %%
# Read in to DFs contd
akas = pd.read_csv(akas_url, sep = '\t', low_memory = False)

# %%
# Read in to DFs contd
ratings = pd.read_csv(ratings_url, sep = '\t', low_memory = False)

# %%
# Give one of our DFs a look
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
# Data cleaning steps
basics.replace({'\\N':np.nan}, inplace = True)

# %%
# We can see that it worked in row 3
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
# Check duplicates
basics.duplicated().sum()
# Out:
# 0

# %%
# Check na
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle           11
# originalTitle          11
# isAdult                 1
# startYear         1255400
# endYear           9258965
# runtimeMinutes    6800352
# genres             430766
# dtype: int64

# %%
# Get more information
basics.describe()
# Out:
#            tconst  titleType  primaryTitle originalTitle  isAdult startYear  \
# count     9357313    9357313       9357302       9357302  9357312   8101913
# unique    9357313         11       4282647       4303377        8       150
# top     tt0000001  tvEpisode  Episode #1.1  Episode #1.1        0      2021
# freq            1    7064744         45721         45721  9066728    435798
#
#        endYear runtimeMinutes   genres
# count    98348        2556961  8926547
# unique      95            877     2329
# top       2017             30    Drama
# freq      5996         145454  1063310

# %%
# Get more information
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357313 entries, 0 to 9357312
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 642.5+ MB

# %%
# Drop null in runtime an genre columns
basics = basics.dropna(subset = ['runtimeMinutes', 'genres'])

# %%
# See updates
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            1
# originalTitle           1
# isAdult                 0
# startYear           62968
# endYear           2442508
# runtimeMinutes          0
# genres                  0
# dtype: int64

# %%
# Drop entire endYear column (all values are null)
basics = basics.drop(columns = 'endYear')

# %%
# Filter out documentaries in genre
is_doc = basics['genres'].str.contains('documentary', case = False)
basics = basics[~is_doc]

# %%
# View changes
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
# 5  tt0000006     short       Chinese Opium Den       Chinese Opium Den
#
#   isAdult startYear runtimeMinutes                    genres
# 1       0      1892              5           Animation,Short
# 2       0      1892              4  Animation,Comedy,Romance
# 3       0      1892             12           Animation,Short
# 4       0      1893              1              Comedy,Short
# 5       0      1894              1                     Short

# %%
# Filter out all titles EXCEPT movies
is_movie = basics['titleType'].str.contains('movie', case = False)
basics = basics[is_movie]

# %%
# View changes
basics.head()
# Out:
#         tconst titleType                    primaryTitle  \
# 8    tt0000009     movie                      Miss Jerry
# 570  tt0000574     movie     The Story of the Kelly Gang
# 587  tt0000591     movie                The Prodigal Son
# 672  tt0000679     movie  The Fairylogue and Radio-Plays
# 930  tt0000941     movie                  Locura de amor
#
#                       originalTitle isAdult startYear runtimeMinutes  \
# 8                        Miss Jerry       0      1894             45
# 570     The Story of the Kelly Gang       0      1906             70
# 587               L'enfant prodigue       0      1907             90
# 672  The Fairylogue and Radio-Plays       0      1908            120
# 930                  Locura de amor       0      1909             45
#
#                          genres
# 8                       Romance
# 570  Action,Adventure,Biography
# 587                       Drama
# 672           Adventure,Fantasy
# 930                       Drama

# %%
# View dtype and years for startYear
basics['startYear'].value_counts()
# Out:
# 2018    10598
# 2017    10469
# 2019    10344
# 2016    10187
# 2015     9721
#         ...
# 1907        2
# 1894        1
# 1906        1
# 1908        1
# 2026        1
# Name: startYear, Length: 122, dtype: int64

# %%
# Change dtype to float (this will be inclusive to the null values)
basics['startYear'] = basics['startYear'].astype(float)

# %%
# Filter start year to include only years between 2000 and 2020
basics.loc[(basics['startYear'] >= 2000) & (basics['startYear'] <= 2020)]
# Out:
#             tconst titleType  \
# 34793    tt0035423     movie
# 61096    tt0062336     movie
# 67642    tt0069049     movie
# 77936    tt0079644     movie
# 86772    tt0088751     movie
# ...            ...       ...
# 9356995  tt9916192   tvMovie
# 9357033  tt9916270     movie
# 9357078  tt9916362     movie
# 9357162  tt9916538     movie
# 9357235  tt9916692   tvMovie
#
#                                               primaryTitle  \
# 34793                                       Kate & Leopold
# 61096    The Tango of the Widower and Its Distorting Mi...
# 67642                           The Other Side of the Wind
# 77936                                        November 1828
# 86772                                    The Naked Monster
# ...                                                    ...
# 9356995         Danielle Darrieux: Il est poli d'être gai!
# 9357033                           Il talento del calabrone
# 9357078                                              Coven
# 9357162                                Kuambil Lagi Hatiku
# 9357235                    Teatroteka: Czlowiek bez twarzy
#
#                                       originalTitle isAdult  startYear  \
# 34793                                Kate & Leopold       0     2001.0
# 61096     El Tango del Viudo y Su Espejo Deformante       0     2020.0
# 67642                    The Other Side of the Wind       0     2018.0
# 77936                                 November 1828       0     2001.0
# 86772                             The Naked Monster       0     2005.0
# ...                                             ...     ...        ...
# 9356995  Danielle Darrieux: Il est poli d'être gai!       0     2019.0
# 9357033                    Il talento del calabrone       0     2020.0
# 9357078                                    Akelarre       0     2020.0
# 9357162                         Kuambil Lagi Hatiku       0     2019.0
# 9357235             Teatroteka: Czlowiek bez twarzy       0     2015.0
#
#         runtimeMinutes                  genres
# 34793              118  Comedy,Fantasy,Romance
# 61096               70                   Drama
# 67642              122                   Drama
# 77936              140               Drama,War
# 86772              100    Comedy,Horror,Sci-Fi
# ...                ...                     ...
# 9356995             53               Biography
# 9357033             84                Thriller
# 9357078             92           Drama,History
# 9357162            123                   Drama
# 9357235             66                   Drama
#
# [150703 rows x 8 columns]

# %%
# Set start year to only include 2000-2020
basics = basics.loc[(basics['startYear'] >= 2000) & (basics['startYear'] <= 2020)]

# %%
# See that our counts have dropped due to filtering
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150703 entries, 34793 to 9357235
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          150703 non-null  object
#  1   titleType       150703 non-null  object
#  2   primaryTitle    150703 non-null  object
#  3   originalTitle   150703 non-null  object
#  4   isAdult         150703 non-null  object
#  5   startYear       150703 non-null  float64
#  6   runtimeMinutes  150703 non-null  object
#  7   genres          150703 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 10.3+ MB

# %%
# We can see that we have both 'movie' AND 'tvMovie'; drop 'tvMovie'
is_tvmovie = basics['titleType'].str.contains('tvMovie', case = False)
basics = basics[~is_tvmovie]
basics['titleType'].value_counts()
# Out:
# movie    129087
# Name: titleType, dtype: int64

# %% [markdown]
# ### I included a lot of checking steps in the filtering of the 'basics' DF for future reference

# %%
# Move on to eliminating \N from akas and ratings
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
# Replace \N with NaN
akas.replace({'\\N':np.nan}, inplace = True)

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33762801 entries, 0 to 33762800
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 2.0+ GB

# %%
akas.isna().sum()
# Out:
# titleId                   0
# ordering                  0
# title                     5
# region              1868261
# language            6343667
# types              28411220
# attributes         33513311
# isOriginalTitle        2187
# dtype: int64

# %%
# Drop null values in region column
akas = akas.dropna(subset = ['region'])

# %%
# Filter us movies
us_movie = akas['region'].str.contains('us', case = False)
akas = akas[us_movie]

# %%
akas.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
akas.duplicated().sum()
# Out:
# 0

# %%
# Replace \N with NaN
ratings.replace({'\\N':np.nan}, inplace = True)

# %% [markdown]
# Now we will filter out our basics df to only include movies from the US with information from our akas df

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers = basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 34793       True
# 61096       True
# 67642       True
# 77936      False
# 86772       True
#            ...
# 9356985     True
# 9356994     True
# 9357033    False
# 9357078     True
# 9357162    False
# Name: tconst, Length: 129087, dtype: bool

# %%
# Now filter basics
basics = basics[keepers]
basics
# Out:
#             tconst titleType  \
# 34793    tt0035423     movie
# 61096    tt0062336     movie
# 67642    tt0069049     movie
# 86772    tt0088751     movie
# 93908    tt0096056     movie
# ...            ...       ...
# 9356449  tt9914942     movie
# 9356845  tt9915872     movie
# 9356985  tt9916170     movie
# 9356994  tt9916190     movie
# 9357078  tt9916362     movie
#
#                                               primaryTitle  \
# 34793                                       Kate & Leopold
# 61096    The Tango of the Widower and Its Distorting Mi...
# 67642                           The Other Side of the Wind
# 86772                                    The Naked Monster
# 93908                                 Crime and Punishment
# ...                                                    ...
# 9356449                             Life Without Sara Amat
# 9356845                               The Last White Witch
# 9356985                                      The Rehearsal
# 9356994                                          Safeguard
# 9357078                                              Coven
#
#                                      originalTitle isAdult  startYear  \
# 34793                               Kate & Leopold       0     2001.0
# 61096    El Tango del Viudo y Su Espejo Deformante       0     2020.0
# 67642                   The Other Side of the Wind       0     2018.0
# 86772                            The Naked Monster       0     2005.0
# 93908                         Crime and Punishment       0     2002.0
# ...                                            ...     ...        ...
# 9356449                 La vida sense la Sara Amat       0     2019.0
# 9356845                  My Girlfriend is a Wizard       0     2019.0
# 9356985                                   O Ensaio       0     2019.0
# 9356994                                  Safeguard       0     2020.0
# 9357078                                   Akelarre       0     2020.0
#
#         runtimeMinutes                     genres
# 34793              118     Comedy,Fantasy,Romance
# 61096               70                      Drama
# 67642              122                      Drama
# 86772              100       Comedy,Horror,Sci-Fi
# 93908              126                      Drama
# ...                ...                        ...
# 9356449             74                      Drama
# 9356845             97       Comedy,Drama,Fantasy
# 9356985             51                      Drama
# 9356994             95  Action,Adventure,Thriller
# 9357078             92              Drama,History
#
# [74959 rows x 8 columns]

# %%
# View rating df
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1922
# 1  tt0000002            5.8       259
# 2  tt0000003            6.5      1733
# 3  tt0000004            5.6       174
# 4  tt0000005            6.2      2544

# %%
keepers_2 = ratings['tconst'].isin(akas['titleId'])
keepers_2
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 1245807    False
# 1245808     True
# 1245809    False
# 1245810    False
# 1245811    False
# Name: tconst, Length: 1245812, dtype: bool

# %%
# Now filter ratings
ratings = ratings[keepers_2]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1922
# 1        tt0000002            5.8       259
# 4        tt0000005            6.2      2544
# 5        tt0000006            5.1       175
# 6        tt0000007            5.4       797
# ...            ...            ...       ...
# 1245786  tt9916204            8.2       247
# 1245792  tt9916348            8.5        17
# 1245793  tt9916362            6.4      4975
# 1245797  tt9916428            3.8        14
# 1245808  tt9916720            5.3       275
#
# [474125 rows x 3 columns]

# %%
# Making new folder with os
import os
os.makedirs('Data/',exist_ok = True)

# Confirm folder was created
os.listdir("Data/")
# Out:
# ['title_basics.csv.gz', '.ipynb_checkpoints', 'title_ratings.csv.gz']

# %%
# Save basics to a csv in Data folder that was just created
basics.to_csv("Data/title_basics.csv.gz", compression = 'gzip',
                                          index = False)

# %%
# Check that it worked
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  \
# 0                             Kate & Leopold        0     2001.0
# 1  El Tango del Viudo y Su Espejo Deformante        0     2020.0
# 2                 The Other Side of the Wind        0     2018.0
# 3                          The Naked Monster        0     2005.0
# 4                       Crime and Punishment        0     2002.0
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %% [markdown]
# Looks great! Now we will save the other 2

# %%
# Save akas and ratings
akas.to_csv("Data/title_akas.csv.gz", compression = 'gzip',
                                          index = False)
ratings.to_csv("Data/title_ratings.csv.gz", compression = 'gzip',
                                          index = False)

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74959 entries, 0 to 74958
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          74959 non-null  object
#  1   titleType       74959 non-null  object
#  2   primaryTitle    74959 non-null  object
#  3   originalTitle   74959 non-null  object
#  4   isAdult         74959 non-null  int64
#  5   startYear       74959 non-null  float64
#  6   runtimeMinutes  74959 non-null  int64
#  7   genres          74959 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 4.6+ MB

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1365697 entries, 5 to 33762545
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1365697 non-null  object
#  1   ordering         1365697 non-null  int64
#  2   title            1365697 non-null  object
#  3   region           1365697 non-null  object
#  4   language         3716 non-null     object
#  5   types            965971 non-null   object
#  6   attributes       45278 non-null    object
#  7   isOriginalTitle  1364322 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 93.8+ MB

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 474125 entries, 0 to 1245808
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         474125 non-null  object
#  1   averageRating  474125 non-null  float64
#  2   numVotes       474125 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 14.5+ MB
